# %%
# %matplotlib inline

# %% [markdown]
# # General Experiment Runner

# %%
# Imports
import os, numpy as np,pandas as pd
import warnings
warnings.filterwarnings('ignore')
import eegnb
from eegnb import generate_save_fn
from eegnb.devices.eeg import EEG
from eegnb.experiments.ssneuro_studies import face_invert as exp # change when running different experiments
from collections import OrderedDict
import seaborn as sns
from matplotlib import pyplot as plt

# MNE functions
from mne import Epochs,find_events
from mne.decoding import Vectorizer

# EEG-Notebooks functions
from eegnb.analysis.utils2 import load_data,plot_conditions, check_report
from eegnb.datasets import fetch_dataset

# %% [markdown]
# ### Experiment set-up

# %%
# Here we can change the variables that we use for measuring experiments!

board_name = "muse2_bfn" # this can stay the same
experiment = "faces_invert" # this changes depending on the experiment, for the purposes of this notebook it can stay the same
subject_id = 1 # change this each time you have a new participant
session_nb = 1 # change this each time you have a new run
record_duration = 30 # this changes how long each session is

# %%
# Start EEG device
eeg_device = EEG(device=board_name, serial_num='Muse-9BF6') # make sure to replace the serial_num with 'Muse-[your device's serial digits]'

# Create save file name
save_fn = generate_save_fn(board_name, experiment, subject_id, session_nb)
print(save_fn)
# Out:
# C:\Users\vanes\.eegnb\data\faces_invert\local\muse2_bfn\subject0001\session001\recording_2026-06-01-15.23.30.csv

# %% [markdown]
# ### Run experiment
#
# Signal check

# %%
check_report(eeg_device)

# %% [markdown]
# To start the experiment, just run the block of code below after running the previous blocks.

# %%
exp.present(duration = record_duration, subject = subject_id, session = session_nb, ver = 1, eeg=eeg_device, save_fn=save_fn)
# Out:
# Running Trial 0: isGo = 0, ISI = 0.5
# Running Trial 1: isGo = 0, ISI = 0.5
# Running Trial 2: isGo = 0, ISI = 0.5
# Running Trial 3: isGo = 1, ISI = 0.5
# Running Trial 4: isGo = 0, ISI = 0.5
# Running Trial 5: isGo = 0, ISI = 0.5
# Running Trial 6: isGo = 1, ISI = 0.5
# Running Trial 7: isGo = 1, ISI = 0.5
# Running Trial 8: isGo = 0, ISI = 0.5
# Running Trial 9: isGo = 1, ISI = 0.5
# Running Trial 10: isGo = 1, ISI = 0.5
# Running Trial 11: isGo = 0, ISI = 0.5
# Running Trial 12: isGo = 1, ISI = 0.5
# Running Trial 13: isGo = 0, ISI = 0.5
# Running Trial 14: isGo = 0, ISI = 0.5
# Running Trial 15: isGo = 1, ISI = 0.5
# Running Trial 16: isGo = 1, ISI = 0.5
# Running Trial 17: isGo = 1, ISI = 0.5
# Running Trial 18: isGo = 0, ISI = 0.5
# 231.5971 	WARNING 	User requested fullscreen with size [800 600], but screen is actually [1280, 800]. Using actual size
# 232.2430 	WARNING 	TextStim.alignHoriz is deprecated. Use alignText and anchorHoriz attributes instead
# 232.2449 	WARNING 	TextStim.alignHoriz is deprecated. Use alignText and anchorHoriz attributes instead
# 232.2461 	WARNING 	TextStim.alignHoriz is deprecated. Use alignText and anchorHoriz attributes instead
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
