# %%
# %matplotlib inline

# %% [markdown]
# # N170: a visual index of facial recognition
#
# Using this notebook, we will discuss and learn about the N170, an event-related potential that is associated with the perception of faces.

# %%
# Imports
import os, numpy as np,pandas as pd
import warnings
warnings.filterwarnings('ignore')
import eegnb
from eegnb import generate_save_fn
from eegnb.devices.eeg import EEG
from eegnb.experiments.visual_n170 import n170
from collections import OrderedDict
import seaborn as sns
from matplotlib import pyplot as plt

# MNE functions
from mne import Epochs,find_events
from mne.decoding import Vectorizer

# EEG-Notebooks functions
from eegnb.analysis.utils2 import load_data,plot_conditions, check_report
from eegnb.datasets import fetch_dataset
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# There are actually two ways of running experiments using this set-up. Below is one example provided to you for ease of adjusting what it is that you want to test. You can then use this template to build your own variation of an experiment!
#
# ### Experiment set-up

# %%
# Here we can change the variables that we use for measuring experiments!

board_name = "muse2_bfn" # this can stay the same
experiment = "visual-N170" # this changes depending on the experiment, for the purposes of this notebook it can stay the same
subject_id = 1 # change this each time you have a new participant
session_nb = 1 # change this each time you have a new run
record_duration = 120 # this changes how long each session is

# %% [markdown]
# After this set-up, we will want to make sure we're using the right inputs before starting the experiment. Here's one way of looking at the inputs, based on where our data will be saved:

# %%
# Start EEG device
eeg_device = EEG(device=board_name, serial_num='Muse-AF55') # make sure to replace the serial_num with 'Muse-[your device's serial digits]'

# Create save file name
save_fn = generate_save_fn(board_name, experiment, subject_id, session_nb)
print(save_fn)

# %% [markdown]
# If the subject and session are labeled with the right places, then that's where you'll find the data when the file is saved after the experiment runs. This is good to keep in mind for when you go find the data for analysis after.
#
# Also, make sure you run the above cell once before every time you want to record the experiment. You'll see that the recording file name is time-stamped - if you don't run the cell again, you'll save over your old file with a new recording!
#
# ### Run experiment
#
# Before starting an experiment, you want to make sure your data aren't too noisy. One way of doing this is to run a signal quality check:

# %%
check_report(eeg_device)

# %% [markdown]
# To start the experiment, just run the block of code below after running the previous blocks.

# %%
n170.present(duration=record_duration, eeg=eeg_device, save_fn=save_fn)

# %% [markdown]
# If you are running the experiment multiple times, whether that's multiple sessions for a person or with different people, make sure that you are first running the previous cells where you change subject/session and also where the file is saved - otherwise, the files you generate will end up in the wrong folders!
#
# ### Visualize data
#
# Let's get a quick look at the data and see what it looks like. For the record, it should look like this:
#
# ![N170](n170.jpg)

# %%
eegnb_data_path = os.path.join(os.path.expanduser('~/'),'.eegnb', 'data')    

# to load data from a specific subject and session:
subject = 99
session = 1
# make sure that these numbers are correct, or it will run from the last time you used 'subject' and 'session', 
# including from above!

raw = load_data(subject,session,
                experiment='visual-N170', site='local', device_name='muse2_bfn',
                data_dir = eegnb_data_path)
# Out:
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=154864
#     Range : 0 ... 154863 =      0.000 ...   604.934 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=151816
#     Range : 0 ... 151815 =      0.000 ...   593.027 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=143896
#     Range : 0 ... 143895 =      0.000 ...   562.090 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=112276
#     Range : 0 ... 112275 =      0.000 ...   438.574 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=178852
#     Range : 0 ... 178851 =      0.000 ...   698.637 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=30748
#     Range : 0 ... 30747 =      0.000 ...   120.105 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=46108
#     Range : 0 ... 46107 =      0.000 ...   180.105 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=43024
#     Range : 0 ... 43023 =      0.000 ...   168.059 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=85360
#     Range : 0 ... 85359 =      0.000 ...   333.434 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=42640
#     Range : 0 ... 42639 =      0.000 ...   166.559 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=124420
#     Range : 0 ... 124419 =      0.000 ...   486.012 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=30712
#     Range : 0 ... 30711 =      0.000 ...   119.965 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=84904
#     Range : 0 ... 84903 =      0.000 ...   331.652 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=53980
#     Range : 0 ... 53979 =      0.000 ...   210.855 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=30784
#     Range : 0 ... 30783 =      0.000 ...   120.246 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=55768
#     Range : 0 ... 55767 =      0.000 ...   217.840 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=50164
#     Range : 0 ... 50163 =      0.000 ...   195.949 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=52084
#     Range : 0 ... 52083 =      0.000 ...   203.449 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=30760
#     Range : 0 ... 30759 =      0.000 ...   120.152 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=30700
#     Range : 0 ... 30699 =      0.000 ...   119.918 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=66328
#     Range : 0 ... 66327 =      0.000 ...   259.090 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=50764
#     Range : 0 ... 50763 =      0.000 ...   198.293 secs
# Ready.
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# ['TP9', 'Fp1', 'Fp2', 'TP10', 'stim']
# Creating RawArray with float64 data, n_channels=5, n_times=30808
#     Range : 0 ... 30807 =      0.000 ...   120.340 secs
# Ready.

# %% [markdown]
# We're going to do a couple of things here that we won't go into now, but will help the final visual look like what it does above. We'll talk more about this process when we do the analyses!

# %%
raw.filter(1,20, method='iir')
# raw.plot_psd(fmin=1, fmax=30); # visualize power spectrum after filtering

# Create an array containing the timestamps and type of each stimulus (i.e. face or house)
events = find_events(raw)
event_id = {'House': 1, 'Face': 2}

# Create an MNE Epochs object representing all the epochs around stimulus presentation
epochs = Epochs(raw, events=events, event_id=event_id, 
                tmin=-0.1, tmax=0.8, baseline=(-0.1, 0),
                reject={'eeg': 75e-6}, preload=True, 
                verbose=False, picks=[0,3])
print('sample drop %: ', (1 - len(epochs.events)/len(events)) * 100)
epochs
# Out:
# Filtering raw data in 23 contiguous segments
# Setting up band-pass filter from 1 - 20 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 20.00 Hz: -6.02, -6.02 dB
#
# 3397 events found
# Event IDs: [1 2]
# sample drop %:  24.19782160730056
# <Epochs |  2575 events (all good), -0.101562 - 0.800781 sec, baseline -0.1 – 0 sec, ~9.1 MB, data loaded,
#  'House': 1302
#  'Face': 1273>

# %% [markdown]
# We're looking for that sample drop % to be as low as possible. If yours is higher than 15%, check the raw number of trials that have come out. It could be that the original recording was a bit noisy, and that's okay.
#
# Before visualizing the output by running the next cell, check the number of trials that you have (it'll say 'Number of events'). You will want to make sure you have a good number of events for each condition (ideally at least 100 for both face and house).
#
# Here's an example of what the next cell's output will look like (keep in mind this example was made with a lot of trials):
#
# ![results](n170_myplot.png)

# %%
conditions = OrderedDict()
conditions['House'] = [1]
conditions['Face'] = [2]

fig, ax = plot_conditions(epochs, conditions=conditions, 
                          ci=97.5, n_boot=1000, title='',
                          channel_order=[0,1,3,2],
                          diff_waveform=(1, 2))

# %% [markdown]
# Use the below code to subsequently save your plot. Don't forget to change the name of the image file accordingly! Consider saving with the name of the person whose data this is, or anything else that will indicate to you whose file it is (e.g. replace 'name' in 'nameplot' with your name).

# %%
fig.savefig('n170_nameplot.png')

# %% [markdown]
# We will try analyzing only the temporal electrodes, using MNE's in-house visualizations (this is from 2/20/23):

# %%
faces = epochs['Face'].average()
houses = epochs['House'].average()

# %%
import mne

evokeds = dict(faces=faces, houses=houses)
picks = [0, 1]
fig = mne.viz.plot_compare_evokeds(evokeds, picks=picks, combine='mean')
fig
fig[0].savefig('n170_class.png')
# Out:
# combining channels using "mean"
# combining channels using "mean"

# %%
evo_indiv = dict(faces=list(epochs['Face'].iter_evoked()), houses=list(epochs['House'].iter_evoked()))
fig2 = mne.viz.plot_compare_evokeds(evo_indiv, picks=picks, combine='mean')
fig2[0].savefig('n170_class_ci.png')
# Out:
# combining channels using "mean"
# combining channels using "mean"
